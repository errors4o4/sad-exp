# %%
print("Hello")
# Out:
# Hello

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df['Cabin'].isnull().sum()
# Out:
# 327

# %%
df['Age'].sum()
# Out:
# 10050.5

# %%
df['Embarked'].value_counts()
# Out:
# S    270
# C    102
# Q     46
# Name: Embarked, dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
a = df['Age'].sum() /418
a
# Out:
# 24.044258373205743

# %%
df1 = df.drop(['Name', 'Cabin'], axis=1)

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch   Ticket  \
# 0          892         0       3    male  34.5      0      0   330911
# 1          893         1       3  female  47.0      1      0   363272
# 2          894         0       2    male  62.0      0      0   240276
# 3          895         0       3    male  27.0      0      0   315154
# 4          896         1       3  female  22.0      1      1  3101298
#
#       Fare Embarked
# 0   7.8292        Q
# 1   7.0000        S
# 2   9.6875        Q
# 3   8.6625        S
# 4  12.2875        S

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()

df1['Embarked'] = label_encoder.fit_transform(df1['Embarked'])

# %%
df1['Sex'] = label_encoder.fit_transform(df1['Sex'])

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch   Ticket     Fare  \
# 0          892         0       3    1  34.5      0      0   330911   7.8292
# 1          893         1       3    0  47.0      1      0   363272   7.0000
# 2          894         0       2    1  62.0      0      0   240276   9.6875
# 3          895         0       3    1  27.0      0      0   315154   8.6625
# 4          896         1       3    0  22.0      1      1  3101298  12.2875
#
#    Embarked
# 0         1
# 1         2
# 2         1
# 3         2
# 4         2

# %%
df1.corr()
# Out:
# /var/folders/zv/x2lv03fs46n15fxz2b08zwx00000gn/T/ipykernel_16360/473017434.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.023245 -0.026751  0.023245 -0.034102  0.003818
# Survived       -0.023245  1.000000 -0.108615 -1.000000 -0.000013  0.099943
# Pclass         -0.026751 -0.108615  1.000000  0.108615 -0.492143  0.001087
# Sex             0.023245 -1.000000  0.108615  1.000000  0.000013 -0.099943
# Age            -0.034102 -0.000013 -0.492143  0.000013  1.000000 -0.091587
# SibSp           0.003818  0.099943  0.001087 -0.099943 -0.091587  1.000000
# Parch           0.043080  0.159120  0.018721 -0.159120 -0.061249  0.306895
# ...

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df1 = df1.drop(['PassengerId', 'Ticket'], axis=0)

# %%
df1.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  34.5      0      0   7.8292         1
# 1         1       3    0  47.0      1      0   7.0000         2
# 2         0       2    1  62.0      0      0   9.6875         1
# 3         0       3    1  27.0      0      0   8.6625         2
# 4         1       3    0  22.0      1      1  12.2875         2

# %%
df1.isnull().sum()
# Out:
# Survived     0
# Pclass       0
# Sex          0
# Age         86
# SibSp        0
# Parch        0
# Fare         1
# Embarked     0
# dtype: int64

# %%
avg = df1['Age'].sum() / 418

# %%
avg
# Out:
# 28.915602446272647

# %%
df1["Age"].fillna(avg, inplace = True)

# %%
df1.isnull.sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df1.dropna()
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch      Fare  Embarked
# 0           0       3    1  34.500000      0      0    7.8292         1
# 1           1       3    0  47.000000      1      0    7.0000         2
# 2           0       2    1  62.000000      0      0    9.6875         1
# 3           0       3    1  27.000000      0      0    8.6625         2
# 4           1       3    0  22.000000      1      1   12.2875         2
# ..        ...     ...  ...        ...    ...    ...       ...       ...
# 413         0       3    1  24.044258      0      0    8.0500         2
# 414         1       1    0  39.000000      0      0  108.9000         0
# 415         0       3    1  38.500000      0      0    7.2500         2
# 416         0       3    1  24.044258      0      0    8.0500         2
# 417         0       3    1  24.044258      1      1   22.3583         0
#
# [417 rows x 8 columns]

# %%
df1.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  34.5      0      0   7.8292         1
# 1         1       3    0  47.0      1      0   7.0000         2
# 2         0       2    1  62.0      0      0   9.6875         1
# 3         0       3    1  27.0      0      0   8.6625         2
# 4         1       3    0  22.0      1      1  12.2875         2

# %%
df1['Age'].sum()
# Out:
# 12057.806220095694

# %%
df1.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df1 = df1.dropna()

# %%
df1.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
X = df1.drop(columns= 'Survived', axis= 0) # Storing features in X var
Y = df1['Survived'] # Storing target var in Y var

# %%
X.shape
# Out:
# (417, 7)

# %%
Y.shape
# Out:
# (417,)

# %%
from sklearn.model_selection import train_test_split # dividing the data into training and test data
from sklearn.linear_model import LogisticRegression # gives binary answers either yes or no
from sklearn.metrics import accuracy_score

# %%
X_train, Y_train, Y_test, X_test = train_test_split(X, Y, test_size = 0.2, stratify = Y, random_state = 2)

# %%
len(X_train), len(X_test)
# Out:
# (333, 84)

# %%
model = LogisticRegression()

# %%
model.fit(X_train.values, Y_train.values)
# Out:
# /Users/omachrekar/miniforge3/envs/work/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
X_train_prediction = model.predict(X_train.values)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
training_data_accuracy
# Out:
# 1.0

# %%
X_test_prediction = model.predict(X_test.values)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
test_data_accuracy
# Out:
# 1.0
